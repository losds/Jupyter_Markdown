# %% [markdown]
# # Suma de dos numeros
# ## 2 + 3

# %%
2+3
# Out:
# 5

# %% [markdown]
# ***

# %% [markdown]
# ## Evaluar a la potencia
# **2 elevado a cubo**

# %%
2**3
# Out:
# 8

# %% [markdown]
# ---

# %% [markdown]
# # Esto es un titulo para listas
# * Item 1
# * Item 2
#  * Item 2.1
#  * Item 2.2

# %% [markdown]
# ***

# %% [markdown]
# # Una imagen de Data Science

# %% [markdown]
# ![imag.jpg](attachment:imag.jpg)
